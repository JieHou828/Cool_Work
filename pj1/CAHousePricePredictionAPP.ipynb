# %% [markdown]
# # Welcome to the California House Price Prediction APP

# %% [markdown]
# # Click on the following block and press CTRL+ENTER

# %%
# Click here and follow the guidance
# !pip install -q requests
import requests
url = 'https://raw.githubusercontent.com/DesirelessJie/Cool_Work/main/pj1/interactive_interface.ipynb'
r = requests.get(url)
with open('interactive_interface.ipynb', 'w') as f:
    f.write(r.text)

# !pip install -q nbconvert
# !jupyter nbconvert --to script interactive_interface.ipynb
# %run interactive_interface.py
# Out:
# [NbConvertApp] Converting notebook interactive_interface.ipynb to script
# [NbConvertApp] Writing 3661 bytes to interactive_interface.py
# HTML(value="<h2 style='padding-left:60px;'>California House Price Prediction Application</h2>")
# VBox(children=(Text(value='', description='MedInc: ', layout=Layout(width='500px'), placeholder='Median Income…
